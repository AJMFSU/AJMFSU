# %% [markdown]
# <a href="https://colab.research.google.com/github/AJMFSU/AJMFSU/blob/main/LIS4761_5765_Data_Exploration_Amy_McMullin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/diabetes.csv')
df.plot(kind='box')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.shape
# Out:
# (768, 9)

# %%
df = df[df['SkinThickness'] <= 80]
df = df[df['Insulin'] <= 600]
df['Insulin'] = df['Insulin'].replace(0,df['Insulin'].median())

# %%
df['Age'].hist()

# %%
df['Age'].plot.density()

# %%
df['Age'].describe()
# Out:
# count    764.000000
# mean      33.185864
# std       11.701598
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64

# %%
correlation=df.corr(method='pearson')
plt.figure(figsize=(16,10))
sns.heatmap(correlation, annot=True)

# %%
sns.violinplot(x="Outcome", y='Pregnancies', data=df)
plt.show()

# %%
df.plot.scatter(x='SkinThickness', y='BMI')
sns.pairplot(data=df, hue="Outcome")
